# %%
bucket_name = 'sessac-project-13-bucket'
mount_path = '/home/jupyter/dataset'
# !gcsfuse --implicit-dirs {bucket_name} {mount_path}
# Out:
# {"time":"23/11/2023 04:52:47.390632","severity":"INFO","msg":"Start gcsfuse/1.2.0 (Go version go1.21.0) for app \"\" using mount point: /home/jupyter/dataset\n"}

# %%
# !pwd
# Out:
# /home/jupyter

# %%
import os

HOME = os.getcwd()
# basePath = '{}/highway/bbox_highway'.format(HOME)
basePath = os.path.join(HOME, 'highway/bbox_highway')
basePath
# Out:
# '/home/jupyter/highway/bbox_highway'

# %%
from distutils.dir_util import copy_tree

frm = '{}/val/labels'.format(basePath)
to = '{}/train/labels'.format(basePath)
copy_tree(frm, to)
# Out:
# ['/home/jupyter/highway/bbox_highway/train/labels/Suwon_CH01_20200720_1700_MON_9m_NH_highway_TW5_sunny_FHD_084.txt',
#  '/home/jupyter/highway/bbox_highway/train/labels/Suwon_CH04_20200720_1800_MON_9m_NH_highway_OW5_sunny_FHD_051.txt',
#  '/home/jupyter/highway/bbox_highway/train/labels/Suwon_CH03_20200720_2000_MON_9m_NH_highway_OW5_sunny_FHD_022.txt',
#  '/home/jupyter/highway/bbox_highway/train/labels/Suwon_CH03_20201012_1802_MON_9m_RH_highway_OW5_sunny_FHD_027.txt',
#  '/home/jupyter/highway/bbox_highway/train/labels/Suwon_CH04_20201010_1849_SAT_9m_NH_highway_OW5_sunny_FHD_140.txt',
#  '/home/jupyter/highway/bbox_highway/train/labels/Suwon_CH03_20201213_0936_SUN_9m_NH_highway_OW5_snow_FHD_127.txt',
#  '/home/jupyter/highway/bbox_highway/train/labels/Suwon_CH01_20201010_1900_SAT_9m_NH_highway_TW5_sunny_FHD_057.txt',
#  '/home/jupyter/highway/bbox_highway/train/labels/Suwon_CH03_20201213_0936_SUN_9m_NH_highway_OW5_snow_FHD_016.txt',
# ...

# %%
frm = '{}/val/images'.format(basePath)
to = '{}/train/images'.format(basePath)
copy_tree(frm, to)
# Out:
# ['/home/jupyter/highway/bbox_highway/train/images/Suwon_CH02_20201012_1858_MON_9m_RH_highway_TW5_sunny_FHD_016.png',
#  '/home/jupyter/highway/bbox_highway/train/images/Suwon_CH03_20200721_2100_TUE_9m_NH_highway_OW5_sunny_FHD_048.png',
#  '/home/jupyter/highway/bbox_highway/train/images/Suwon_CH02_20200720_2000_MON_9m_NH_highway_TW5_sunny_FHD_095.png',
#  '/home/jupyter/highway/bbox_highway/train/images/Suwon_CH01_20200720_2000_MON_9m_NH_highway_TW5_sunny_FHD_111.png',
#  '/home/jupyter/highway/bbox_highway/train/images/Suwon_CH03_20200721_2100_TUE_9m_NH_highway_OW5_sunny_FHD_012.png',
#  '/home/jupyter/highway/bbox_highway/train/images/Suwon_CH02_20200721_1800_TUE_9m_RH_highway_TW5_sunny_FHD_105.png',
#  '/home/jupyter/highway/bbox_highway/train/images/Suwon_CH01_20200720_2000_MON_9m_NH_highway_TW5_sunny_FHD_112.png',
#  '/home/jupyter/highway/bbox_highway/train/images/Suwon_CH01_20200720_2000_MON_9m_NH_highway_TW5_sunny_FHD_003.png',
# ...
